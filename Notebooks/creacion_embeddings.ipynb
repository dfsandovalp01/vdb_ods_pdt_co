# %% [markdown]
# # Librerías generales

# %%
# %%capture
# %pip install PyPDF2
# %pip install pypdf
# %pip install pdfminer.six
# %pip install langchain
# %pip install zipfile
# %pip install --upgrade --quiet llmsherpa
# %pip install langchain_community
# %pip install tiktoken
# %pip install pandas
# %pip install gensim
# %pip install nltk

# %%
import pandas as pd
import PyPDF2 as pdf2
from ast import literal_eval
from pdfminer.high_level import extract_text
from gensim.models import Word2Vec
import re
from gensim.parsing.preprocessing import strip_punctuation, strip_numeric, strip_short, stem_text
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from langchain.text_splitter import NLTKTextSplitter
from langchain.text_splitter import SpacyTextSplitter
from langchain_community.document_loaders import PyPDFLoader

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')

from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Daniel
# [nltk_data]     B\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\Daniel
# [nltk_data]     B\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Daniel
# [nltk_data]     B\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.

# %% [markdown]
# # Funciones

# %%
a,b = 'áéíóúüñÁÉÍÓÚÜÑ|,."_;:🎀🤷🏻‍♀️🤭🟢⚪️🙏🏻🔪💿💀🔥🚫💸😁😍💜💎💁🏽‍♀️🐟🍍✨👏🏻🌟💞💯🍺〽️❤️💕','aeiouunAEIOUUN                                                 '
trans = str.maketrans(a,b)

def cleanName(_):
  cleaned_text_list = []
  # try:
  _ = _.translate(trans).rstrip()
  # Convierte el texto a minúsculas
  _ = _.lower()

  # Elimina URLs
  _ = re.sub(r'http\S+|www\S+|https\S+', '', _, flags=re.MULTILINE)

  # Elimina las menciones @ y '#' de las redes sociales
  _ = re.sub(r'\@\w+|\#\w+', '', _)

  # Elimina los caracteres de puntuación
  _ = strip_punctuation(_)

  # Elimina los números
  _ = strip_numeric(_)

  # Elimina las palabras cortas
#   _ = strip_short(_,minsize=2)

  # Elimina las palabras comunes (stop words)
  stop_words = set(stopwords.words('spanish'))
  # stop_words = set(stopwords.words('english'))
  word_tokens = word_tokenize(_)
  filtered_text = [word for word in word_tokens if word not in stop_words]
  cleaned_text_list.append(filtered_text)
  # print(cleaned_text_list)
  _ = ' '.join(cleaned_text_list[0]) #.apply(concatenar_lista)
  # except :
  #   _ = _

  return _ #{'text': _}

# %%
import os
# from google.colab import drive
# drive.mount('/content/drive')
current_dir = os.getcwd()
data_dir = os.path.join(current_dir, os.pardir, "data")
os.path.exists(data_dir)
# Out:
# True

# %% [markdown]
# # Muestra PDT para clusters

# %%
import os
pdf_and_text = []
pages = None
# def readZip(dir):
bdl_corpus = pd.DataFrame()
# ruta = '/content/drive/MyDrive/Proyectos/NLP/ODS/Insumos/PDM-ABRIL-30.pdf'
ruta = os.path.join(data_dir,"pdf" ,"27.pdf")

loader = PyPDFLoader(f"{ruta}")
pages = loader.load_and_split()
pages_content=''

for item in pages:
  # print(type(item))
  pages_content = pages_content + item.page_content

pdf_and_text.append({"File Name":'Duitama',"text":pages_content.replace('\n', ' ')})

# %%
# %pip install --upgrade --quiet langchain-text-splitters tiktoken
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# from langchain.text_splitter import RecursiveCharacterTextSplitter, CharacterTextSplitter
from langchain_text_splitters import CharacterTextSplitter
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    model_name="gpt-4",
    chunk_size=100,
    chunk_overlap=0,
)

# text_splitter = RecursiveCharacterTextSplitter(
#     chunk_size = 128,
#     chunk_overlap  = 20,
#     length_function = len,
# )

# text_splitter = CharacterTextSplitter.from_tiktoken_encoder(
#     encoding_name="cl100k_base", chunk_size=256, chunk_overlap=20
# )
documents = text_splitter.split_text(pages_content.replace('\n', '').replace('\uf0b7', ''))

# documents = text_splitter.split_documents(pages)

# %%
documents = [cleanName(doc) for doc in documents]
documents
# Out:
# ['republica colombia departamento choco nit republica colombia departamento choco nit tabla contenido pg presentacion mision vision principios',
#  'premisas enfoques plan desarrollo departamental articulacion planes desarrollo capitulo i diagnostico generalidades departamento',
#  'localizacion limites contexto demografico poblacion total estructura demografica',
#  'dinamica demografica indicadores dinamica poblacion movilidad forzada dinamica migratoria',
#  'linea estrategica choco incluyente corresponsable generar confianza sector salud abordaje efectos salud determinantes',
#  'analisis mortalidad mortalidad general grandes causas mortalidad especifica subgrupo',
#  'mortalidad materno – infantil ninez tasas especificas mortalidad ninez analisis desigualdad mortalidad materno – infantil ninez',
#  'determinantes estructurales identificacion prioridades identificadas mortalidad general especifica materno –infantil analisis morbilidad',
#  'principales causas morbilidad morbilidad especifica salud mental analisis poblacion condicion discapacidad identificacion prioridades',
#  'p rincipales morbilidad aspectos relevantes sector salud sector educacion equipamientos educativos equipamientos educativos',
#  'escolar analisis docentes departamento equipamientos educativos educacion superior sector cultura republica colombia departamento',
#  'choco nit espacios participacion municipales cultura sistema participacion departamental cultura declaratorias patrimoniales departamental nacional',
#  'actual infraestructura cultural area bibliotecas publicas infraestructura bibliotecas publicas prestacion',
#  'servicios casas culturas municipales fuentes financiacion cultural municipios instancias culturales',
#  'operatividad instancias sector deporte recreacion equipamientos recreacion deporte sector servicios',
#  'publicos saneamiento basico acueducto alcantarillado aseo',
#  'gas natural saneamiento basico infraestructura agua potable saneamiento',
#  'subregion atrato infraestructura agua potable saneamiento subregion darien infraestructura agua potable',
#  'saneamiento subregion san juan infraestructura agua potable saneamiento subregion pacifico infraestructura agua',
#  'potable saneamiento subregion baudo pobreza sector poblaciones especificas',
#  'primera infancia infancia adolescencia descripcion trabajo infantil departamento choco identificacion agentes',
#  'snbf territorio oferta social ofertas programas direccion familias comunidades regional choco mesa departamental participacion',
#  'ninos ninas adolescentes juventud adulto mayor mujer gene ro',
#  'poblacion lgtbi victimas restitucion tierras',
#  'discapacitados grupos etnicos',
#  'comunidades negras republica colombia departamento choco nit comunidades indigenas',
#  'situaciones problematicas puntuales concretas linea estrategica choco ambiente sostenible generar confianza',
#  'sector medio ambiente problematica ambiental potencialidades regionales problematica recurso hidrico',
#  'degradacion fuentes hidricas hidrografia usos recurso agua contaminacion marinocostera',
#  'calidad agua consumo humano calidad agua rio atrato',
#  'calidad agua rio san juan calidad aguas rio cabi potencial hidrico',
#  'cuenca rio atrato cuenca rio san juan',
#  'cuenca rio baudo deterioro ecosistemas boscosos degradacion bosque mineria',
#  'aluvial metales preciosos oro platino departamento choco degradacion bosque aprovechamiento forestal determinantes ambientales',
#  'sentencia t “ rio atrato sujeto derechos ” orden relativa plan erradicacion mineria ilegal',
#  'orden relativa plan seguridad alimentaria concertacion articulacion negocios verdes',
#  'avances implementacion programa regional negocios verdes pacifico area jurisdiccion codechoco gestion riesgo desastres',
#  'linea estrategica choco productivo competitivo generar confianza estructura socioeconomica',
#  'contexto socioeconomico general localizacion distribucion actividades product ivas empleo',
#  'agricultura desarrollo rural actividad minera choco turismo',
#  'choco sitios turisticos choco infraestruc tura transporte',
#  'ciencia tecnologia telecomunicaciones republica colombia departamento choco nit situaciones problematicas',
#  'puntuales concretas linea estrategica choco paz seguridad justicia garantia derechos humanos generando confianza',
#  'paz municipios priorizados objeto pdet seguridad justicia',
#  'sistema penitenciario ca rcelario sistema responsabilidad penal adolescentes',
#  'poblacion proceso reintegracion reincorporacion planes desarrollo enfoque territorial etnico – pdete',
#  'trata personas situacion poblacion migrante derechos humanos linea',
#  'estrategica choco gobernable transparente generar confianza divers idad institucionalidades etnicas region',
#  'cooperacion internacional departamento choco diagnostico sector administrativo capitulo ii marco estrategico',
#  'linea estrategica choco incluyente corresponsable generar confianza estrategias salud',
#  'estrategias educacion estrategias cultura estrategias deporte recreacion',
#  'estrategias servicios publicos saneamiento basico estrategias vivienda',
#  'estrategias poblaciones especificas estrategias politicas publicas libertad religion culto',
#  'linea estrategica choco ambiente sostenible generar confianza estrategias medio ambiente',
#  'estrate gias negocios verdes estrategias gestion riesgo desastres',
#  'linea estrategica choco productivo competitivo generar confianza estrategias agricul tura',
#  'estrategias turismo estructura emprendimiento competitividad mineria',
#  'republica colombia departamento choco nit infraestructura equipamentos',
#  'ciencia tecnologia telecomunicacion linea estrategica choco paz seguridad justicia garantia derechos humanos generando confianza',
#  'paz seguridad',
#  'justicia derechos humanos linea estrategica choco gobernable transparente generar',
#  'confianza estrategias gobernabilidad autosuficiencia transparencia eficacia administracion',
#  'estrategias saneamiento fiscal financiero funcion publica exitosa transparente estrategias capacidad institucional garantizar derecho pa rticipacion ciudadana',
#  'estrategias programa capacitacion asistencia tecnica orientada desarrollo competencias ley',
#  'estrategias acciones etnodesarrollo subregiones',
#  'estrategias desarrollo comunitario capitulo iii plan plurianual inversiones diagnostico financiero',
#  'analisis comportamiento ingresos analisis comportamiento gastos funcionamiento',
#  'fuentes financiacion plan plurianual inversion departamento choco –',
#  'proyectos estrategicos proyectos estrategicos plan nacional desarrollo proyectos estrategicos',
#  'compromisos comite civico salvacion choco gobierno departamental proyectos estrategicos subregiones capitulo iv',
#  'seguimiento evaluacion anexos republica colombia departamento choco nit lista tablas',
#  'pg tabla articulacion plan nacional desarrollo plan desarrollo departamental tabla municipios regiones departamento tabla distribucion poblacion sexo departamento choco tabla poblacion area',
#  'residencia sexo municipios departamento choco tabla indicadores demograficos tabla indices demograficos tabla dinamica poblacion departa mento choc –',
#  'tabla poblacion victimizada desplazamiento grupo edad sexo choco tabla indice demografico migrantes tabla semaforizacion mortal idad departamento choco tabla',
#  'tasa total mortalidad infantil menores ano departamento choco – tabla tasa mortalidad infantil menores ano grandes grupos ninas departamento choco – tabla tasa mortalidad',
#  'infantil ninos menores ano departamento choco – tabla tasas especificas mortalidad infantil ninez total menores anos choco – tabla tasas especificas mortalidad',
#  'infantil ninez ninas menores anos choco – tabla tasa mortalidad infantil ninez ninos anos choco tabla tasas especificas mortalidad',
#  'infantil ninez menores cinco anos departamento choco tabla tasas especificas mortalidad menores cinco anos ninas departamento choco tabla tasas especificas mortalidad menores cinco anos ninos departam',
#  'ento choco tabla semaforizacion tendencia mortalidad materno – infantil ninez departamento choco tabla analisis desigualdades m ortalidad nbi choco',
#  'tabla razon mortalidad materna tasa mortalidad neonatal etnia departamento choco – tabla indicadores razon mortalidad materna tasa mortalidad neonatal area residencia depart amento choco –',
#  'tabla identificacion prioridades salud d epartamento choco tabla principales causas morbilidad hombres departamento choco – republica colombia departamento choco nit tabla',
#  'principales causas morbilidad mujeres departamento choco – tabla morbilidad salud mental tabla distribucion alteracio nes permanentes choco tabla prioridades morbilidad atendida alto',
#  'costo eventos precursores notificacion obliga toria choco tabla analisis cierre brecha sector salud tabla pactos comunitarios subregionales tabla numero establecimientos educativos',
#  'tabla registro matriculas tabla matricu area geografica tabla atencion estudiantes niveles tabla tasas cobertura bruta tabla tasas cobertura neta',
#  'tabla poblacion sistema escolar tabla estadisticas educacion escolar media tabla numero sedes educativas nivel total zonas urbanas rurales junio',
#  'tabla numero docentes ocupados choco nivel educativo indicando porcentaje tan ocupados zona urbana tabla numero matriculados choco nivel educativo indicando porcentaje estan matriculados zona urbana tabla numero',
#  'alumnos potenciales choco nivel educativo i ndicando porcentaje habitan zona urbana segun proyecciones poblacion dane edades simples partir censo tabla establecimientos ensenanza superior tabla',
#  'resumen estadisticas – tabla tasa cobertura bruta educacion superior tabla matricula sector tabla analisis cierre brecha sector educacion tabla pactos comunitarios',
#  'subregionales tabla declaratorias patrimonio materi departamental nacional tabla declaratorias patrimonio inmater ial departamental nacional tabla relacion escenarios artisticos culturales departamento choco',
#  'tabla municipios cue ntan mas bibliotecas tabla proyectos presentados aprobados impuesto nacional consumo telefonia movil sector cultura tabla necesidades subregiones tabla pactos comunitarios subregionales',
#  'tabla equipamientos deportivos presentes partamento tabla pactos comunitarios subregionales tabla cobertura existente redes',
#  'tabla cobertura exist ente alcantarillado tabla sitios disposicion republica colombia departamento',
#  'choco nit tabla tipos sistema acueducto tabla cobertura existente redes tabla',
#  'cobertura alcantarillado diferentes municipios tabla sitio disposicion tabla tipos sistema acueducto tabla existencia planta tratamiento agua potable diferentes municipios',
#  'tabla cobertura existente redes tabla cobertura alcantarillado diferentes municipios tabla sitio disposicion',
#  'tabla sistemas acueducto tabla existencia planta tratamiento agua potable tabla cobertura redes acueducto',
#  'subregion pacifico tabla cobertura alcantarillado municipios subregion pacifico tabla sitios disposicion subregion pacifico',
#  'tabla sistema acueducto subregion baudo tabla sistema alcantarillado subregion baudo tabla sitios disposicion subregion baudo',
#  'tabla analisis cierre brecha sector servicios publicos tabla pactos comunitarios subregionales tabla resumen general idades demograficas regional',
#  'tabla datos poblacionales tabla indicadores prioritarios vulneracion derechos infancia adolescencia tabla ninos ninas adolescentes',
#  'jovene s modalidad familia bienestar paz tabla municipios priorizados plan accion mitigacion riesgo desnutricion infantil tabla instituciones',
#  'ofrecen servicios l primera infancia infancia adolescencia familia departamento choco tabla plataformas juventudes conformadas tabla organizaciones juveniles base cuales relacionamiento directo',
#  'tabla cantidad cupos programa joven tabla cantidad cupos programa mil primeros empleos tabla nacimiento cuya madre anos',
#  'tabla homicidios jovenes anos tabla jovenes anos victimas desplazamiento forzado conflicto armado',
#  'tabla desaparicion forzada jovenes anos tabla educacion media secundaria ano tabla matriculas educacion superior segun sexo tabla graduados educacion superior',
#  'tabla poblacion joven anos recluidos tabla poblacion adulta republica colombia departamento',
#  'choco nit tabla ubicacion ancianatos departamento choco tabla centros vida centros dia dia siguientes municipios',
#  'tabla existencia comite adultos mayor diferentes municipios tabla municipios choco acuerdos politica publica equidad genero mujeres',
#  'tabla hogares jefatura femenina tabla porcentaje hogares jefatura femenina total nacional regional departamento area tabla lesiones fatales –',
#  'quibdo tabla datos departament choco tabla datos desagregados personas enero',
#  'tabla datos desagregados hechos enero tabla desagregado rango edad enero tabla desagregado razon genero enero',
#  'tabla desagregado etnia enero tabla desagregado anos tabla reporte departamental actividades',
#  'tabla programacion reuniones subcomite nacional prevencion proteccion garantias repeticion tabla informacion territorial restitucion tierras territorios tabla',
#  'pactos comunitarios subregionales tabla determinantes ambientales tabla inventario negocios verdes registrado ventanilla codechoco diciembre',
#  'tabla pactos comunitari subregionales tabla sismos mas destacados departamento choco tabla pactos comunitarios subregionales',
#  'tabla pactos comunitarios subregionales tabla are as protegidas departamento choco tabla titularidad minera actual departamento choco',
#  'tabla pactos comunitarios subregionales tabla pactos comunitarios subregionales tabla elementos red primaria carreteras choco tomado red vial',
#  'criterio tecnico segundo semestre invias tabla jerarquizacion vial existente departamento tabla pactos comunitarios subregionales tabla pactos',
#  'comunitarios subregionales tabla pactos comunitarios subregionales tabla centro penitenciario anayancy tabla persona l centro penitenciario anayancy',
#  'tabla pactos comunitarios subregionales tabla agenda programatica cooperacion internacional inversion tabla estrategias salud',
#  'tabla estrategias educacion republica colombia departamento choco nit tabla estrategias cultura',
#  'tabla estrategias deporte recreacion tabla estrategias servicios publicos saneamiento basico',
#  'tabla estrategias vivienda tabla estrategias poblacion especifica',
#  'tabla estrategias politicas publicas libertad religion culto tabla estrategias medio ambiente tabla',
#  'estrategias negocios verdes tabla estrategias gestion riesgo tabla estrategias agricultura',
#  'tabla estrategias turismo tabla estrategias emprendimiento empresarismo tabla estrategias mineria',
#  'tabla estrategias infraestructura tabla estrategias equipamentos tabla',
#  'estrategias ciencia tecnologia telecomunicaciones tabla estrategias paz tabla estrategias seguridad',
#  'tabla estrategias justicia tabla estrategias derechos humanos tabla estrategias gobernabilidad autosuficiencia transparencia',
#  'eficacia administracion tabla estrategias saneamiento fiscal financiero funcion publica exitosa transparente tabla estrategias capacidad institucional garantizar derecho participacion',
#  'ciudadana tabla estrategias programa capacitacion asistencia tecnica orientada desarrollo competencias ley tabla estrategias acciones etnodesarrollo subregiones',
#  'tabla estrategias desarrollo comunitario tabla comportamiento ingresos tabla analisis',
#  'comportamiento ingresos tabla gastos funcionamiento neto gf tabla compromisos rentas reorientadas tabla',
#  'compromisos embargos sentencias judicial tabla comportamiento ingresos corrientes libre destinacion tabla plan plurianual inversiones departamento choco',
#  'nit presencia historica grupos armados ilegales departamento comienza principios decada anos agudiza anos situacion coincide intensificacion dinamica nacional conflicto armado particularmente norte centro occidente pais region uraba extiende',
#  'hacia zonas colonizacion internas bajo medio atrato vias comunican departamento resto pais medellin carmen atrato quibdo pereira pueblo rico istmina quibdo constituyendo region terminos conflicto compromete departamentos antioquia cordoba ch oco caldas',
#  'risaralda partir aumento departamento choco presion grupos auto defensa incremento notablemente atrato provenientes uraba antioqueno pertenecian autodefensas campesinas cordoba uraba accu avance dio mediante uso terror afectacion tejido social',
#  'fragmentacion organizacion comunitaria profiriendo amenazas cometiendo asesinatos desapariciones lideres lideresas movimientos sociales qu reclamaban autonomia territorios etnicos ejercian resistencia frente accionar grupos armados tambien efectuaron bloqueos economicos doblegar comunidades afectar fuentes abastecimiento',
#  'guerrilla gran parte desplazamientos masivos realizaron via acuatica utilizando botes lanchas pangas minoria hicieron via terrestre ocurrio paralelamente desarrollo intensas operaciones militares frentes farc parte fuerza publica adicionalmente',
#  'vienen registrando enfrentamientos directos guerrillas autodefensas ” observatorio programa presidencial ddhh dih vicepresidencia republica p empi atreves articulo ley realizara procesos intervencion psicologicas cada ninos ninas adolescentes',
#  'derechos amenazados inobservados vulnerado psicologo tendra presente unas rutas proceso orientacion sensibilizacion familias verificando problematicas mas frecuentes hogar visita posible intervencion tendran cuenta alta permanencia situacion vida calle consumo sustancias psicoactivas disc apacidad madres gestantes periodo lactancia',
#  'victima violencia sexual situacion trabajo infantil embarazo adolescentes cuenta modalidad inicial equipo psicosocial estara presente servicios atencion observacion provisional ninos ninas adolescentes proceso administrativo restablecimiento republica colombia departamento choco nit',
#  'derecho mientras autoridad administrativa decide medida restablecimiento derecho equipo psicosocial tendra pre sente hora abordaje talleres encuentros brindandoles acompanamientos seguimientos manera grupal individual atreves encuesta diagnostico familiar valoracion psicologica ninos ninas adolescentes familias n cuenta',
#  'particularidades miembros grupo familiar principales actividades economicas explotacion forestal intensiva mineria actividad maderera orienta industria aserrio alta pluviosidad departamento mas altas mundo hace dificil agricultura embargo realiza cultivos platano maiz arroz cacao coco',
#  'explotacion minera gran parte actividades hacen litoral san juan munici pio da mayor explotacion metales municipio condoto capital mundial platino gran parte explotacion minera particular oro realiza manera ilegal termina siendo fuente financiacion grup margen',
#  ...]

# %%
# [txt['text'] for txt in pdf_and_text[0] if txt['File Name']=='Duitama']
print(len(documents[600].split(' ')))#.page_content
# [doc for doc in documents if f'|' in doc]
# len(documents)
# print(ascii('d'))
# type(pages)
# documents
# Out:
# 36

# %%
# %%capture
# %pip install -U sentence-transformers
# %pip install torch

# %%
import torch
from sentence_transformers import SentenceTransformer, util

# model = SentenceTransformer("multi-qa-mpnet-base-cos-v1")
# model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")
model = SentenceTransformer("hackathon-pln-es/paraphrase-spanish-distilroberta")
# Out:
# c:\Users\Daniel B\miniconda3\envs\nlp_base\lib\site-packages\huggingface_hub\file_download.py:159: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Daniel B\.cache\huggingface\hub\models--hackathon-pln-es--paraphrase-spanish-distilroberta. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# c:\Users\Daniel B\miniconda3\envs\nlp_base\lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
# Verifica si CUDA (GPU) está disponible
if torch.cuda.is_available():
    print("CUDA (GPU) está disponible.")
    print("Número de GPUs disponibles:", torch.cuda.device_count())
    print("Nombre de la GPU:", torch.cuda.get_device_name(0))
else:
    print("CUDA (GPU) no está disponible.")
# Out:
# CUDA (GPU) no está disponible.

# %%
passage_embeddings = model.encode(documents,batch_size=64,show_progress_bar=True)#, device='cuda')
# Out:
# Batches:  98%|█████████▊| 49/50 [14:27<00:17, 17.70s/it]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 passage_embeddings = model.encode(documents,batch_size=64,show_progress_bar=True)#, device='cuda')
#
# File c:\Users\Daniel B\miniconda3\envs\nlp_base\lib\site-packages\sentence_transformers\SentenceTransformer.py:517, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     514 features.update(extra_features)
#     516 with torch.no_grad():
# --> 517     out_features = self.forward(features)
#     518     if self.device.type == "hpu":
#     519         out_features = copy.deepcopy(out_features)
#
# File c:\Users\Daniel B\miniconda3\envs\nlp_base\lib\site-packages\torch\nn\modules\container.py:219, in Sequential.forward(self, input)
#     217 def forward(self, input):
#     218     for module in self:
# --> 219         input = module(input)
#     220     return input
#
# File c:\Users\Daniel B\miniconda3\envs\nlp_base\lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Daniel B\miniconda3\envs\nlp_base\lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\Daniel B\miniconda3\envs\nlp_base\lib\site-packages\sentence_transformers\models\Transformer.py:118, in Transformer.forward(self, features)
#     115 if "token_type_ids" in features:
#     116     trans_features["token_type_ids"] = features["token_type_ids"]
# --> 118 output_states = self.auto_model(**trans_features, return_dict=False)
#     119 output_tokens = output_states[0]
#     121 features.update({"token_embeddings": output_tokens, "attention_mask": features["attention_mask"]})
#
# File c:\Users\Daniel B\miniconda3\envs\nlp_base\lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Daniel B\miniconda3\envs\nlp_base\lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\Daniel B\miniconda3\envs\nlp_base\lib\site-packages\transformers\models\roberta\modeling_roberta.py:825, in RobertaModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     818 # Prepare head mask if needed
#     819 # 1.0 in head_mask indicate we keep the head
#     820 # attention_probs has shape bsz x n_heads x N x N
#     821 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#     822 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#     823 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# --> 825 embedding_output = self.embeddings(
#     826     input_ids=input_ids,
#     827     position_ids=position_ids,
#     828     token_type_ids=token_type_ids,
#     829     inputs_embeds=inputs_embeds,
#     830     past_key_values_length=past_key_values_length,
#     831 )
#     832 encoder_outputs = self.encoder(
#     833     embedding_output,
#     834     attention_mask=extended_attention_mask,
#    (...)
#     842     return_dict=return_dict,
#     843 )
#     844 sequence_output = encoder_outputs[0]
#
# File c:\Users\Daniel B\miniconda3\envs\nlp_base\lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Daniel B\miniconda3\envs\nlp_base\lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\Daniel B\miniconda3\envs\nlp_base\lib\site-packages\transformers\models\roberta\modeling_roberta.py:115, in RobertaEmbeddings.forward(self, input_ids, token_type_ids, position_ids, inputs_embeds, past_key_values_length)
#     112         token_type_ids = torch.zeros(input_shape, dtype=torch.long, device=self.position_ids.device)
#     114 if inputs_embeds is None:
# --> 115     inputs_embeds = self.word_embeddings(input_ids)
#     116 token_type_embeddings = self.token_type_embeddings(token_type_ids)
#     118 embeddings = inputs_embeds + token_type_embeddings
#
# File c:\Users\Daniel B\miniconda3\envs\nlp_base\lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Daniel B\miniconda3\envs\nlp_base\lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\Daniel B\miniconda3\envs\nlp_base\lib\site-packages\torch\nn\modules\sparse.py:164, in Embedding.forward(self, input)
#     163 def forward(self, input: Tensor) -> Tensor:
# --> 164     return F.embedding(
#     165         input, self.weight, self.padding_idx, self.max_norm,
#     166         self.norm_type, self.scale_grad_by_freq, self.sparse)
#
# File c:\Users\Daniel B\miniconda3\envs\nlp_base\lib\site-packages\torch\nn\functional.py:2267, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2261     # Note [embedding_renorm set_grad_enabled]
#    2262     # XXX: equivalent to
#    2263     # with torch.no_grad():
#    2264     #   torch.embedding_renorm_
#    2265     # remove once script supports set_grad_enabled
#    2266     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2267 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# RuntimeError: Expected tensor for argument #1 'indices' to have one of the following scalar types: Long, Int; but got torch.FloatTensor instead (while checking arguments for embedding)

# %%
pd.DataFrame(passage_embeddings)#.to_csv(os.path.join(data_dir, "embeddings", "27.csv"), index=False)
# Out:
#            0         1         2         3         4         5         6    \
# 0     0.042367 -0.071221  0.048507 -0.045486 -0.002688 -0.057612 -0.004107
# 1     0.015170  0.015056 -0.023920 -0.038653 -0.033825 -0.046896 -0.019105
# 2     0.127279 -0.054075 -0.044775 -0.070976  0.005485 -0.026359  0.043829
# 3     0.055317  0.042160 -0.046554  0.014982 -0.077174 -0.065201  0.031923
# 4    -0.013688 -0.036379 -0.024030 -0.000450 -0.025156  0.028489 -0.045820
# ...        ...       ...       ...       ...       ...       ...       ...
# 3146  0.085621  0.040211  0.028736 -0.041677 -0.008269  0.000217 -0.065977
# 3147  0.054842 -0.009338 -0.014763 -0.032103  0.034911 -0.032972  0.037725
# 3148  0.081281 -0.005785  0.037971 -0.056628 -0.007179 -0.001117 -0.057305
# 3149  0.032226  0.087562 -0.025763 -0.024795  0.019876  0.041715  0.065621
# 3150  0.006781 -0.012290  0.001025 -0.014086 -0.049674 -0.041009 -0.007547
#
#            7         8         9    ...       374       375       376  \
# 0     0.045282  0.022898  0.029578  ... -0.007496 -0.046049  0.038519
# 1     0.082348 -0.044354  0.031231  ...  0.000516  0.065708 -0.059714
# 2     0.044072 -0.054648  0.001396  ...  0.064478  0.046135 -0.010347
# 3     0.096568 -0.065272  0.014883  ...  0.008923  0.020193  0.007194
# 4     0.084136 -0.060630 -0.025134  ... -0.017208 -0.037420  0.043487
# ...        ...       ...       ...  ...       ...       ...       ...
# 3146  0.122317 -0.018017  0.080615  ...  0.054620 -0.013872  0.019714
# 3147  0.048795  0.012302 -0.000961  ...  0.019112  0.017625  0.136299
# 3148  0.127010 -0.015358  0.055377  ...  0.013710 -0.074688  0.019592
# 3149  0.079587 -0.052099  0.041287  ... -0.038746 -0.101054  0.116830
# 3150  0.060259  0.031690  0.000020  ... -0.017002 -0.047264  0.007248
#
#            377       378       379       380       381       382       383
# 0    -0.069133 -0.080755  0.011094  0.052599 -0.009545 -0.067781  0.000760
# 1    -0.002351 -0.042863  0.014531  0.017540 -0.018974 -0.034688 -0.077253
# 2    -0.007818 -0.050186  0.040959 -0.047093  0.005894 -0.007718 -0.011703
# 3     0.037258 -0.091998 -0.070002  0.068594 -0.013958 -0.000622 -0.051965
# 4    -0.020917 -0.063246 -0.015969  0.100551  0.061250 -0.003592 -0.046413
# ...        ...       ...       ...       ...       ...       ...       ...
# 3146 -0.021273 -0.078078 -0.006569  0.016842 -0.022563 -0.024558 -0.024049
# 3147  0.046935  0.071095  0.041286  0.035396  0.068310 -0.084779 -0.048458
# 3148  0.001136 -0.060667 -0.017555  0.005003 -0.011887 -0.067822 -0.040591
# 3149  0.056482 -0.002732  0.045615  0.091708  0.022293 -0.068483 -0.087590
# 3150 -0.039198 -0.081903  0.027812  0.015203 -0.000147 -0.053403 -0.015694
#
# [3151 rows x 384 columns]

# %%
df_doc = pd.DataFrame(
    {"Documentos" : documents,
     'embeddings' : passage_embeddings.tolist()}
)
df_doc.head()
# passage_embeddings.shape
# Out:
#                                           Documentos  \
# 0  1  REPUBLICA DE COLOMBIA  DEPARTAMENTO DEL CHO...
# 1  PREMISAS       22 ENFOQUES DEL PLAN DE DESARRO...
# 2  1.1.1  Localización y Limites         32 1.1.2...
# 3  1.1.2.3  Dinámica demográfica         40 1.1.2...
# 4  42  1.2 LÍNEA ESTRATÉGICA 1. UN CHOCÓ INCLUYEN...
#
#                                           embeddings
# 0  [0.04236729070544243, -0.0712207481265068, 0.0...
# 1  [0.015169757418334484, 0.015055638737976551, -...
# 2  [0.12727926671504974, -0.05407460033893585, -0...
# 3  [0.05531660094857216, 0.04216017946600914, -0....
# 4  [-0.013687951490283012, -0.03637908026576042, ...

# %%
# df_doc.to_csv('/content/drive/MyDrive/Proyectos/NLP/ODS/output/df_doc.txt', sep='|')

# %%
query_embedding = model.encode(['Proyecciones de la población'])
df_doc['similarity'] = df_doc['embeddings'].apply(lambda x: util.cos_sim(x,query_embedding))
df_doc.sort_values('similarity', ascending=False).head()
# Out:
#                                             Documentos  \
# 210  proceso de prevención a los factores de riesgo...
# 391  quintero, el cargua, rincón del cargua, las Am...
# 223  ser uno de los pilares del accionar de todas l...
# 232  por la ESE reflejan incremento de vigencia a v...
# 326  proyectos nuevos. Esta adquisición de predios ...
#
#                                             embeddings          similarity
# 210  [-0.0302952378988266, 0.07318558543920517, -0....  [[tensor(0.7136)]]
# 391  [-0.02997242659330368, 0.08857964724302292, -0...  [[tensor(0.6184)]]
# 223  [-0.011530615389347076, 0.07240030914545059, -...  [[tensor(0.6083)]]
# 232  [0.0012987136142328382, 0.014815008267760277, ...  [[tensor(0.5924)]]
# 326  [-0.02225414291024208, 0.05412407964468002, -0...  [[tensor(0.5849)]]

# %%
df_doc.sort_values('similarity', ascending=False).head().reset_index(drop=True).iloc[1,0]
# Out:
# 'quintero, el cargua, rincón del cargua, las Américas, Boyacá, Colombia, san Juan Bosco, los Alpes, Camilo torres, simón bolívar, barrio las lajas.;  De los delitos puestos en conocimiento la población femenina ha asumido 984 contra 831 que se le han efectuado a la población masculina. Para este nuevo periodo (2020'

# %% [markdown]
# # Ejemplo clusters

# %%
# %%capture
# !pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.42.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.3.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.26.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.3.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 3.6 MB/s eta 0:00:00
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 46.1 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, sentence-transformers
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.20 nvidia-nvtx-cu12-12.1.105 sentence-transformers-3.0.1

# %%
from sklearn.cluster import AgglomerativeClustering
from sentence_transformers import SentenceTransformer
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
embedder = SentenceTransformer("all-MiniLM-L6-v2")

# Corpus with example sentences
corpus = [
    "A man is eating food.",
    "A man is eating a piece of bread.",
    "A man is eating pasta.",
    "The girl is carrying a baby.",
    "The baby is carried by the woman",
    "A man is riding a horse.",
    "A man is riding a white horse on an enclosed ground.",
    "A monkey is playing drums.",
    "Someone in a gorilla costume is playing a set of drums.",
    "A cheetah is running behind its prey.",
    "A cheetah chases prey on across a field.",
]
corpus_embeddings = embedder.encode(corpus)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
type(corpus_embeddings)#.shape()
# Out:
# numpy.ndarray

# %%
# Some models don't automatically normalize the embeddings, in which case you should normalize the embeddings:
# corpus_embeddings = corpus_embeddings / np.linalg.norm(corpus_embeddings, axis=1, keepdims=True)

# Perform agglomerative clustering
clustering_model = AgglomerativeClustering(
    n_clusters=None, distance_threshold=1.5
)  # , affinity='cosine', linkage='average', distance_threshold=0.4)
clustering_model.fit(corpus_embeddings)
cluster_assignment = clustering_model.labels_

clustered_sentences = {}
for sentence_id, cluster_id in enumerate(cluster_assignment):
    if cluster_id not in clustered_sentences:
        clustered_sentences[cluster_id] = []

    clustered_sentences[cluster_id].append(corpus[sentence_id])

for i, cluster in clustered_sentences.items():
    print("Cluster ", i + 1)
    print(cluster)
    print("")
# Out:
# Cluster  1
# ['A man is eating food.', 'A man is eating a piece of bread.', 'A man is eating pasta.']
#
# Cluster  5
# ['The girl is carrying a baby.', 'The baby is carried by the woman']
#
# Cluster  2
# ['A man is riding a horse.', 'A man is riding a white horse on an enclosed ground.']
#
# Cluster  3
# ['A monkey is playing drums.', 'Someone in a gorilla costume is playing a set of drums.']
#
# Cluster  4
# ['A cheetah is running behind its prey.', 'A cheetah chases prey on across a field.']
